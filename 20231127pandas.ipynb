# %% [markdown]
# <a href="https://colab.research.google.com/github/wnyngj/DT-/blob/main/20231127pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#numpy, #pandas, #matplotlib

# !pip install numpy pandas matplotlib #시프트 엔터

# %%
import pandas as pd

# %%
pd.__version__

# %%
#pandas의 데이터는 (1)series- 컬럼 1개, (2)dataframe- 컬럼 2개이상

data=['a','b','c','d','e']
se = pd.Series(data)
se.index
se.values
type(se)
se[2] #indexing
se[0:3] #slicing

data=
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
#raw data 날 것의 데이터
data = {
    'country' : ["kor", "usa", "china", "japan"],
    'rank' : [1,2,3,4],
    'grade' : ["A", "B", "C", "D"],
}

df=pd.DataFrame(data)
df
# Out:
#   country  rank grade
# 0     kor     1     A
# 1     usa     2     B
# 2   china     3     C
# 3   japan     4     D

# %%
df.to_csv("test.csv") #표형태를 파일로 저장하기

# %%
#(1) 데이터 셀렉션
#데이터에서 내가 원하는 데이터를 가져오는 방법

#df.칼럼, df['컬럼명']
df.country
df['country'] #두개이상의 데이터를 불러올 수 있음
df[['country','rank']] #그치만 리스트 형태로 불러와야함

#변수형태로 담아와보기
needs_col=['rank','country']
df[needs_col]
# Out:
#    rank country
# 0     1     kor
# 1     2     usa
# 2     3   china
# 3     4   japan

# %%
#df.loc[인덱스명, 컬럼명]
df.loc[0:3,['country','rank']]
# Out:
#   country  rank
# 0     kor     1
# 1     usa     2
# 2   china     3
# 3   japan     4

# %%
#데이터를 추가또는 삭제하는 방법
df['president']=['yoon','biden','jinping','kishida']
df
# Out:
#   country  rank grade president
# 0     kor     1     A      yoon
# 1     usa     2     B     biden
# 2   china     3     C   jinping
# 3   japan     4     D   kishida

# %%
#행 데이터를 추가하는 방법
df.loc[3]=['singapore',5,'A','tharman']
df
# Out:
#      country  rank grade president
# 0        kor     1     A      yoon
# 1        usa     2     B     biden
# 2      china     3     C   jinping
# 3  singapore     5     A   tharman

# %%
#데이터를 제거하는 방법 -> drop()
df.drop(columns='grade', inplace=True) #지운 데이터 저장하는 법 inplace=True
df.drop(2)
#인덱스는 숫자만 넣어도 됨
df_china_drop
# Out:
#      country  rank president
# 0        kor     1      yoon
# 1        usa     2     biden
# 3  singapore     5   tharman

# %%
#집합함수(Aggregation)
#EDA-데이터를 훑는 과정

df.sum()
df.mean()
df.max() #숫자의 최댓값 -> 여기선 랭크
df.describe() #컬럼이 2-30개 있을 때 평균, 최솟값 바로 구할 수 있는 중요한 함수
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    4 non-null      object
#  1   rank       4 non-null      int64
#  2   president  4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 224.0+ bytes
# <ipython-input-28-a923ccbb10ad>:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
